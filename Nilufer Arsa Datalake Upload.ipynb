# %% [markdown]
# # Nilufer Arsa Birim Degerleri - Datalake Upload
#
# Bu notebook Databricks'te calisir. `Nilufer Arsa Verisi Indir (Local).ipynb`
# ile lokalde indirilip Databricks'e (DBFS/Volume) manuel yuklenen CSV'yi okur
# ve data lake'e (bronze katman) yazar.
#
# Kullanim: Notebook'u calistirmadan once ust kisimdaki `source_path` widget'ina
# yukledigin CSV'nin Databricks path'ini yaz (orn. `dbfs:/FileStore/nilufer/nilufer_arsa_birim_degerleri.csv`
# veya bir Unity Catalog Volume path'i).

# %%
# %run "./Utils"

# %%
dbutils.widgets.text("source_path", "", "Databricks source path (csv)")

SOURCE_PATH = dbutils.widgets.get("source_path")

if not SOURCE_PATH:
    raise ValueError("source_path widget'i bos. Yukledigin CSV'nin Databricks path'ini gir.")

print("Kaynak path:", SOURCE_PATH)

# %%
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, DoubleType

schema = StructType([
    StructField("mahalle_adi", StringType(), True),
    StructField("cadde_sokak_adi", StringType(), True),
    StructField("nitelik_adi", StringType(), True),
    StructField("yil", IntegerType(), True),
    StructField("arsa_birim_degeri", DoubleType(), True),
])

df_spark = (
    spark.read
    .option("header", True)
    .schema(schema)
    .csv(SOURCE_PATH)
)

print("Satir sayisi (partition bazli, tahmini):", df_spark.rdd.getNumPartitions(), "partition")
display(df_spark.limit(10))

# %%
write_to_datalake(
    df_spark,
    "abfss://axetproject@ozandatalake001.dfs.core.windows.net/axet_bronze/nilufer_arsa_birim_degerleri/"
)
